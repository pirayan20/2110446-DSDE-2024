# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Load the "ModifiedEdibleMushroom.csv" data from the link below (note: this data set has been preliminarily prepared.) again.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/pvateekul/2110446_DSDE_2023s2/main/DataSet/hed2020_dataset.csv')

# %%
data.head()
# Out:
#    id label cap-shape cap-surface bruises odor gill-attachment gill-spacing  \
# 0   1     p         x           s       t    p               f            c
# 1   2     e         x           s       t    a               f            c
# 2   3     e         b           s       t    l               f            c
# 3   4     p         x           y       t    p               f            c
# 4   5     e         x           s       f    n               f            w
#
#   gill-size stalk-shape  ... ring-number ring-type spore-print-color  \
# 0         n           e  ...           o         p                 k
# 1         b           e  ...           o         p                 n
# 2         b           e  ...           o         p                 n
# 3         n           e  ...           o         p                 k
# 4         b           t  ...           o         e                 n
#
#   population habitat cap-color-rate gill-color-rate veil-color-rate  \
# 0          s       u            1.0             3.0             1.0
# 1          n       g            2.0             3.0             1.0
# 2          n       m            3.0             1.0             1.0
# 3          s       u            3.0             1.0             1.0
# 4          a       g            4.0             3.0             1.0
#
#   stalk-color-above-ring-rate  stalk-color-below-ring-rate
# 0                         1.0                          1.0
# 1                         1.0                          1.0
# 2                         1.0                          1.0
# 3                         1.0                          1.0
# 4                         1.0                          1.0
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. Choose edible mushrooms only.

# %%
data = data[data.label == 'e']

# %% [markdown]
# # 3.  Only the variables below have been selected to describe the distinctive characteristics of edible mushrooms
# <font color=red> 'cap-color-rate', 'stalk-color-above-ring-rate'

# %%
num_col = ['cap-color-rate', 'stalk-color-above-ring-rate']
data = data[num_col]

# %%
data.isnull().sum()
# Out:
# cap-color-rate                  6
# stalk-color-above-ring-rate    28
# dtype: int64

# %% [markdown]
# # 4. Provide a proper data preprocessing as follows:
#
# - Fill missing with mean
#
# - Standardize variables with Standard Scaler

# %%
data.fillna(data.mean(), inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# get & fit the scaler
scaler = StandardScaler()
data[num_col] = scaler.fit_transform(data[:])

# %% [markdown]
# # 5. K-means clustering with 5 clusters and seed = 2020.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=2020).fit(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['cluster'] = kmeans.labels_

# %%
data
# Out:
#       cap-color-rate  stalk-color-above-ring-rate  cluster
# 1          -0.735005                    -0.747608        2
# 2          -0.234180                    -0.747608        0
# 4           0.266645                    -0.747608        0
# 5          -0.735005                    -0.747608        2
# 6          -0.234180                    -0.747608        0
# ...              ...                          ...      ...
# 5815       -1.235830                     2.432790        1
# 5819       -1.235830                     2.432790        1
# 5820       -1.235830                     2.432790        1
# 5821       -1.235830                     2.432790        1
# 5823       -1.235830                     2.432790        1
#
# [2104 rows x 3 columns]

# %% [markdown]
# # 6. Show the centroid of each cluster.

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=num_col)
centroids
# Out:
#    cap-color-rate  stalk-color-above-ring-rate
# 0        0.413618                    -0.375369
# 1       -1.235830                     2.306584
# 2       -1.229062                    -0.293547
# 3        2.505966                    -0.747608
# 4        1.209313                     1.902724

# %% [markdown]
# # 7. Convert the centroid value to the original scale

# %%
centroids[num_col] = scaler.inverse_transform(centroids[num_col])
centroids
# Out:
#    cap-color-rate  stalk-color-above-ring-rate
# 0        4.293462                     1.702251
# 1        1.000000                     6.761905
# 2        1.013514                     1.856611
# 3        8.471264                     1.000000
# 4        5.882230                     6.000000
